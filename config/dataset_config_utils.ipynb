# %%
import glob
import os

# Parcourir tous les fichiers .txt dans le dossier courant
for filename in glob.glob("/home/antoine/GenD/config/datasets/DF40/test/*.txt"):
    print(filename)
    # Ouvrir et lire le fichier
    with open(filename, 'r', encoding='utf-8') as f:
        lines = f.readlines()

    # Enlever toutes les lignes qui contiennent "landmarks"
    filtered_lines = [line for line in lines if "landmarks" not in line]

    # Trier les lignes
    filtered_lines.sort()

    # Enregistrer le fichier
    with open(filename, 'w', encoding='utf-8') as f:
        f.writelines(filtered_lines)
# Out:
# /home/antoine/GenD/config/datasets/DF40/test/faceswap_cdf.txt
# /home/antoine/GenD/config/datasets/DF40/test/dit_ff.txt
# /home/antoine/GenD/config/datasets/DF40/test/whichfaceisreal_ff.txt
# /home/antoine/GenD/config/datasets/DF40/test/starganv2_ff.txt
# /home/antoine/GenD/config/datasets/DF40/test/ddim_cdf.txt
# /home/antoine/GenD/config/datasets/DF40/test/uniface_cdf.txt
# /home/antoine/GenD/config/datasets/DF40/test/styleclip_ff.txt
# /home/antoine/GenD/config/datasets/DF40/test/mcnet_cdf.txt
# /home/antoine/GenD/config/datasets/DF40/test/rddm_cdf.txt
# /home/antoine/GenD/config/datasets/DF40/test/sadtalker_ff.txt
# /home/antoine/GenD/config/datasets/DF40/test/sit_ff.txt
# /home/antoine/GenD/config/datasets/DF40/test/tpsm_cdf.txt
# /home/antoine/GenD/config/datasets/DF40/test/danet_cdf.txt
# /home/antoine/GenD/config/datasets/DF40/test/collabdiff_ff.txt
# /home/antoine/GenD/config/datasets/DF40/test/tpsm_ff.txt
# /home/antoine/GenD/config/datasets/DF40/test/stylegan2.txt
# ...

# %%
import glob
import os

# Parcourir tous les fichiers .txt dans le dossier courant
for filename in glob.glob("/home/antoine/GenD/config/datasets/DF40/test/*.txt"):
    print(filename)
    # Ouvrir et lire le fichier
    with open(filename, 'r', encoding='utf-8') as f:
        lines = f.readlines()

    # Enlever toutes les lignes qui contiennent "landmarks"
    cdf_lines = [line for line in lines if "/ff/" not in line]
    ff_lines = [line for line in lines if "/ff/" in line]

    # Trier les lignes
    cdf_lines.sort()
    ff_lines.sort()

    new_filename_cdf = "/".join(filename.split("/")[0:-1]) + "/" + filename.split("/")[-1].split(".")[0] + "_cdf" + ".txt"
    print(new_filename_cdf)

    new_filename_ff = "/".join(filename.split("/")[0:-1]) + "/" + filename.split("/")[-1].split(".")[0] + "_ff" + ".txt"
    print(new_filename_ff)

    # Enregistrer le fichier
    with open(new_filename_cdf, 'w', encoding='utf-8') as f:
        f.writelines(cdf_lines)

     # Enregistrer le fichier
    with open(new_filename_ff, 'w', encoding='utf-8') as f:
        f.writelines(ff_lines)
# Out:
# /home/antoine/GenD/config/datasets/DF40/test/stylegan3.txt
# /home/antoine/GenD/config/datasets/DF40/test/stylegan3_cdf.txt
# /home/antoine/GenD/config/datasets/DF40/test/stylegan3_ff.txt
# /home/antoine/GenD/config/datasets/DF40/test/stylegan2.txt
# /home/antoine/GenD/config/datasets/DF40/test/stylegan2_cdf.txt
# /home/antoine/GenD/config/datasets/DF40/test/stylegan2_ff.txt
# /home/antoine/GenD/config/datasets/DF40/test/oneshotfree.txt
# /home/antoine/GenD/config/datasets/DF40/test/oneshotfree_cdf.txt
# /home/antoine/GenD/config/datasets/DF40/test/oneshotfree_ff.txt
# /home/antoine/GenD/config/datasets/DF40/test/stargan.txt
# /home/antoine/GenD/config/datasets/DF40/test/stargan_cdf.txt
# /home/antoine/GenD/config/datasets/DF40/test/stargan_ff.txt
# /home/antoine/GenD/config/datasets/DF40/test/mraa.txt
# /home/antoine/GenD/config/datasets/DF40/test/mraa_cdf.txt
# /home/antoine/GenD/config/datasets/DF40/test/mraa_ff.txt
# /home/antoine/GenD/config/datasets/DF40/test/fomm.txt
# ...

# %%
import glob
import os

file_to_process = [
    "/home/antoine/GenD/config/datasets/DF40/test/styleganxl.txt",
    "/home/antoine/GenD/config/datasets/DF40/test/tpsm.txt",
    "/home/antoine/GenD/config/datasets/DF40/test/uniface.txt",
    "/home/antoine/GenD/config/datasets/DF40/test/vqgan.txt",
    "/home/antoine/GenD/config/datasets/DF40/test/wav2lip.txt",
    "/home/antoine/GenD/config/datasets/DF40/test/whichfaceisreal.txt"
]

for filename in file_to_process:
    print(filename)
    # Ouvrir et lire le fichier
    with open(filename, 'r', encoding='utf-8') as f:
        lines = f.readlines()

    # Enlever toutes les lignes qui contiennent "landmarks"
    cdf_lines = [line for line in lines if "/ff/" not in line]
    ff_lines = [line for line in lines if "/ff/" in line]

    # Trier les lignes
    cdf_lines.sort()
    ff_lines.sort()

    new_filename_cdf = "/".join(filename.split("/")[0:-1]) + "/" + filename.split("/")[-1].split(".")[0] + "_cdf" + ".txt"
    print(new_filename_cdf)

    new_filename_ff = "/".join(filename.split("/")[0:-1]) + "/" + filename.split("/")[-1].split(".")[0] + "_ff" + ".txt"
    print(new_filename_ff)

    # Enregistrer le fichier
    with open(new_filename_cdf, 'w', encoding='utf-8') as f:
        f.writelines(cdf_lines)

     # Enregistrer le fichier
    with open(new_filename_ff, 'w', encoding='utf-8') as f:
        f.writelines(ff_lines)
# Out:
# /home/antoine/GenD/config/datasets/DF40/test/styleganxl.txt
# /home/antoine/GenD/config/datasets/DF40/test/styleganxl_cdf.txt
# /home/antoine/GenD/config/datasets/DF40/test/styleganxl_ff.txt
# /home/antoine/GenD/config/datasets/DF40/test/tpsm.txt
# /home/antoine/GenD/config/datasets/DF40/test/tpsm_cdf.txt
# /home/antoine/GenD/config/datasets/DF40/test/tpsm_ff.txt
# /home/antoine/GenD/config/datasets/DF40/test/uniface.txt
# /home/antoine/GenD/config/datasets/DF40/test/uniface_cdf.txt
# /home/antoine/GenD/config/datasets/DF40/test/uniface_ff.txt
# /home/antoine/GenD/config/datasets/DF40/test/vqgan.txt
# /home/antoine/GenD/config/datasets/DF40/test/vqgan_cdf.txt
# /home/antoine/GenD/config/datasets/DF40/test/vqgan_ff.txt
# /home/antoine/GenD/config/datasets/DF40/test/wav2lip.txt
# /home/antoine/GenD/config/datasets/DF40/test/wav2lip_cdf.txt
# /home/antoine/GenD/config/datasets/DF40/test/wav2lip_ff.txt
# /home/antoine/GenD/config/datasets/DF40/test/whichfaceisreal.txt
# ...
